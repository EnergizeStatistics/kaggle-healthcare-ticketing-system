# %% [markdown]
# # Healthcare Ticketing Topic Classification #

# %% [markdown]
# ## Prepare Tools ##

# %%
# utility
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import Counter
from itertools import islice
########

# text pre-processing
import nltk # natural language processing
from nltk.corpus import stopwords, wordnet # stop words
# from nltk.stem.snowball import SnowballStemmer # stemming
from nltk import pos_tag, word_tokenize # identify POS tag, required by lemmatizer
from nltk.stem import WordNetLemmatizer # lemmatization
########

# extraction
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelBinarizer
########

from sklearn.model_selection import train_test_split
########

# deep learning
# pre-processing
from keras.preprocessing import sequence
from keras.layers.embeddings import Embedding

# simple multilayer perceptron
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

# LSTM
from keras.layers import LSTM

# CNN
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# overfitting remedy
from keras import regularizers
########

# performance
from sklearn.metrics import confusion_matrix
########

# fix random seed for reproducibility
seed = 0
np.random.seed(seed)

# %%
working_dir = "/home/lee/Documents/Datasets for GitHub/kaggle-healthcare-ticketing-system/"

# download to working directory
nltk.download(['stopwords', 'wordnet', 'punkt', 'averaged_perceptron_tagger'], download_dir=working_dir)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lee/Documents/Datasets for GitHub/kaggle-
# [nltk_data]     healthcare-ticketing-system/...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/lee/Documents/Datasets for GitHub/kaggle-
# [nltk_data]     healthcare-ticketing-system/...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/lee/Documents/Datasets
# [nltk_data]     for GitHub/kaggle-healthcare-ticketing-system/...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/lee/Documents/Datasets for GitHub/kaggle-
# [nltk_data]     healthcare-ticketing-system/...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## Load and Inspect Data ##

# %%
df = pd.read_csv(working_dir+'train.csv')

# %%
print("dataframe shape: {}".format(df.shape))
print("\n")
print("preview: \n{}".format(df.head()))
print("\n")
print("first 5 conversations:")
for i in list(range(5)):
    print(str(i)+" "+df.loc[i, 'converse']+"\n")
# Out:
# dataframe shape: (48699, 2)
#
#
# preview:
#               categories                                           converse
# 0  QUERIES FROM PHARMACY  please to verify instructions for drugname pat...
# 1        NEW APPOINTMENT  lmovm for patients mother to and schd rov trac...
# 2                 OTHERS  labtype and insurance approval other incoming ...
# 3                 OTHERS  clinical list changes medfusion secure electro...
# 4     MEDICATION RELATED  wants to wean off medication work phone name d...
#
#
# first 5 conversations:
# 0 please to verify instructions for drugname patients wi from pharmacy target reason for call details please to verify instructions for drugname patients will be picking up Rx timephrase clarified Rx with pharmacy lisa gilligan rn
#
# 1 lmovm for patients mother to and schd rov tracy dominguez am kellee currie pm rhonda fanning
#
# 2 labtype and insurance approval other incoming name lpn clinical review for cigna reason for call details to inform that there is not enough information provided but patients can be approved for an at home labtype whitney will fax this will need to be filled out and sent if there are any questions please whintey at rna follow routed to wendy upchurch lisa mohamed rn auth obtained and routed to sleep schedulers tammy byrd fyi wendy upchurch clinical list changes
#
# 3 clinical list changes medfusion secure electronic message subject genetic testing hello jennifer i just wanted to update you on where we stand as far as genetic testing is concerned we are working on building a standard order for the testing the testing will be administered at which is on the ground floor in the building next door to where you were seen today i will contact you once this order has been sent and you will be able to obtain a cost estimate from i look forward to speaking with you soon angela s cma end of message body route responses to me ansmith notify when read failure notice days message queued for notanimer timephrase
#
# 4 wants to wean off medication work phone name dad other patients dad request to sw rn to discuss patients care now that timephrase pm lmtcb regarding dad question timephrase pm lmtcb x patient dad was asking if patients could be weaned off medicine since last seizure was months ago patients is currently taken lamictal mg tab in am tabs in pm he was hoping to try weaning the patients since she was out of school for the summer provider notified timephrase pm i would suggest we arrange for a sleep deprived labtype to make sure she is truly outgrown them i can order and have it done promptly so we can meet seen to discuss weaning her medication md timephrase pm dad says please order labtype provider notified timephrase

# %% [markdown]
# Observations:
# * No punctuations.
# * People's names are prevalent.
# * There are many abbreviations I cannot decipher. Providers are likely to use the same abbreviations though so this ought not to be a problem.
# * Many terms are masked for confidentiality reasons, such as "drugname" and "timephrase".

# %% [markdown]
# ### Check for Missing ###

# %%
print('Is any "converse" missing?', df['converse'].isnull().values.any())
# Out:
# Is any "converse" missing? True

# %% [markdown]
# Need to fill missing with spaces then.

# %% [markdown]
# ### Check Class Balance ###

# %%
print("# of unique categories: {}".format(df["categories"].nunique()))
print("\n")
print("unique categories: {}".format(set(df["categories"])))
print("\n")
print("label frequencies: \n{}".format(df["categories"].value_counts()))
# Out:
# # of unique categories: 21
#
#
# unique categories: {'MEDICATION RELATED', 'CHANGE OF HOSPITAL', 'QUERIES FROM PHARMACY', 'FOLLOW UP ON PREVIOUS REQUEST', 'NEW APPOINTMENT', 'JUNK', 'CHANGE OF PROVIDER', 'QUERY ON CURRENT APPOINTMENT', 'SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)', 'PROVIDER', 'OTHERS', 'CANCELLATION', 'REFILL', 'RUNNING LATE TO APPOINTMENT', 'RESCHEDULING', 'PRIOR AUTHORIZATION', 'SHARING OF LAB RECORDS (FAX, E-MAIL, ETC.)', 'LAB RESULTS', 'SYMPTOMS', 'QUERIES FROM INSURANCE FIRM', 'CHANGE OF PHARMACY'}
#
#
# label frequencies:
# MEDICATION RELATED                               9010
# NEW APPOINTMENT                                  8907
# REFILL                                           8347
# OTHERS                                           6253
# SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)    3018
# LAB RESULTS                                      2253
# PROVIDER                                         1677
# QUERIES FROM PHARMACY                            1464
# RESCHEDULING                                     1383
# SHARING OF LAB RECORDS (FAX, E-MAIL, ETC.)       1212
# PRIOR AUTHORIZATION                              1043
# SYMPTOMS                                         1021
# CHANGE OF PROVIDER                                811
# RUNNING LATE TO APPOINTMENT                       590
# CANCELLATION                                      564
# QUERY ON CURRENT APPOINTMENT                      559
# FOLLOW UP ON PREVIOUS REQUEST                     304
# CHANGE OF HOSPITAL                                127
# QUERIES FROM INSURANCE FIRM                        91
# CHANGE OF PHARMACY                                 47
# JUNK                                               18
# Name: categories, dtype: int64

# %% [markdown]
# Classes are relatively well balanced. However I (admittedly not an expert on categorizing tickets) see overlaps among the categories. Now look at a few arbitrary conversations to check for overlapping.

# %%
print(df.iloc[40, 0])
print(df.iloc[40, 1])
print("\n")
print(df.iloc[59, 0])
print(df.iloc[59, 1])
print("\n")
print(df.iloc[61, 0])
print(df.iloc[61, 1])
# Out:
# SYMPTOMS
# fyi increased numbness phone patient triage adult numbness in any part of the body patients and states that shes having increased numbness in her left leg and ankle please back to advise timephrase pm started timephrase got worst on sunday has not changed since feels she is having a flair feels as if tournique on left ankle appointment scheduled for phone completed appointment scheduled patient mary morton lpn timephrase pm
#
#
# MEDICATION RELATED
# patients now experiencing numbness to rt side patient triage adult patients is still taking prednisone as prescribed patients is now experiencing numbness to rt side of her forehead down the rt side of her face to her rt forearm her labtype is scheduled for in the timephrase noted proceed with labtype can always check and see if there are openings timephrase to get her in sooner stacey carroll anp rna follow rn labtype department to check availability for timephrase they do not have openings for a double labtype notified patients of staceys advisement and she voiced understanding phone completed patient verbalized understanding of instructions joyce schwartz rn
#
#
# MEDICATION RELATED
# patients wants to discuss left arm numbness patients refused to see a midle other patients wants to discuss left arm numbness patients refused to see a midlevel and wants to know what pkn thinks she should do at this point patients states woke with left arm numbnessheaviness on timephrase states feels better now should she come in what should she do please advise thanks lisa gilligan rn if she slept on her left arm she have pinched the nerve temporarily if the symptoms are improving and it did not involve her face or leg i think she can wait and see if it gets better over the next days p md spoke with patients regarding instructions per pkn verbalized understanding lisa gilligan rn clinical list changes medications updated changed medication from drugname mg tabs hydrocodone po q hours prn must last days to drugname mg tabs hydrocodone po q hours prn must last days signed changed medication from nucynta mg tabs tapentadol hcl po qhrs prn to

# %% [markdown]
# All the 3 conversations involve patients reporting numbness in detail. But record 40 is categorized as "SYMPTOMS" and 59 and 61 "MEDICATION RELATED". Personally I might categorize all of them as "SYMPTOMS". I wonder how strong the agreement will be between two human experts categorizing the same ticket - here I do not expect the machine learning models to exceed human performance.

# %% [markdown]
# ## Preprocess the Text ##

# %%
nltk.data.path.append(working_dir)

# replace NaN
df['converse_filled'] = df['converse'].fillna(value=' ')

# remove punctuation
df['removepunc'] = df['converse_filled'].str.replace('[^\w\s]',' ')

# lower casing
df['lower'] = df['removepunc'].str.lower()

# tokenize and lemmatize
# adjective, adverb, noun, verb = 'JJ', 'RB', 'NN', 'VB'
map_pos = {'NN': 'n', 'JJ': 'a', 'RB': 'r', 'VB': 'v'}

def lemmatize_after_pos(review):
    lemma_review = []
    for word, tag in pos_tag(word_tokenize(review)):
        wntag = tag[0:2]
        wntag = map_pos[wntag] if wntag in ['NN', 'JJ', 'RB', 'VB'] else None
        lemma = WordNetLemmatizer().lemmatize(word, wntag) if wntag else word
        lemma_review.append(lemma)
    return lemma_review

df['lemmatized'] = df['lower'].apply(lambda x: lemmatize_after_pos(x))

# remove stopwords
stop = stopwords.words('english')
df['removestop'] = df['lemmatized'].apply(lambda x: [item for item in x if item not in stop])

df['processed_converse'] = df['removestop'].apply(lambda x: ' '.join(x))

# %%
print("inspect results:")
for i in list(range(5)):
    print(i, df.loc[i, 'processed_converse'])
# Out:
# inspect results:
# 0 please verify instruction drugname patient wi pharmacy target reason call detail please verify instruction drugname patient pick rx timephrase clarify rx pharmacy lisa gilligan rn
# 1 lmovm patient mother schd rov tracy dominguez kellee currie pm rhonda fanning
# 2 labtype insurance approval incoming name lpn clinical review cigna reason call detail inform enough information provide patient approve home labtype whitney fax need fill send question please whintey rna follow rout wendy upchurch lisa mohamed rn auth obtain rout sleep scheduler tammy byrd fyi wendy upchurch clinical list change
# 3 clinical list change medfusion secure electronic message subject genetic testing hello jennifer want update stand far genetic testing concern work build standard order test testing administer ground floor building next door see today contact order send able obtain cost estimate look forward speak soon angela cma end message body route response ansmith notify read failure notice day message queue notanimer timephrase
# 4 want wean medication work phone name dad patient dad request sw rn discuss patient care timephrase pm lmtcb regard dad question timephrase pm lmtcb x patient dad ask patient could wean medicine since last seizure month ago patient currently take lamictal mg tab tab pm hop try wean patient since school summer provider notify timephrase pm would suggest arrange sleep deprive labtype make sure truly outgrown order promptly meet see discuss wean medication md timephrase pm dad say please order labtype provider notify timephrase

# %% [markdown]
# Cleaning went as expected.
#
# We need to have an idea of the length of conversations to bound conversations for a future step, then we pick a bound, truncating longer ones and zero-padding shorter ones.

# %%
print("distribution of word counts:\n{}".format(df['processed_converse'].str.len().describe()))
print("95th, 99th, 99.9th percentiles: {}".format(np.percentile(df['processed_converse'].str.len(), [95, 99, 99.9])))
# Out:
# distribution of word counts:
# count    48699.000000
# mean       353.912996
# std        211.505234
# min          0.000000
# 25%        177.000000
# 50%        319.000000
# 75%        532.000000
# max       1738.000000
# Name: processed_converse, dtype: float64
# 95th, 99th, 99.9th percentiles: [703. 794. 940.]

# %% [markdown]
# ## Prepare Training Dataset ##

# %%
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df['processed_converse'], \
                                                                df["categories"], \
                                                                test_size=0.1, random_state=0);

# %% [markdown]
# How many unique words are there in the training dataset? Their frequencies?

# %%
all_words_count = dict(Counter(" ".join(df_X_train.values.tolist()).split(" ")).items())

# %% [markdown]
# Look at words with low frequencies.

# %%
# tokens with frequencies < 5
infrequent_tokens = dict({(k, v) for k, v in all_words_count.items() if v < 5})

# %%
# print({(k, v) for k, v in all_words_count.items() if v < 5})
# output is very long, making this notebook hard to read

# look at 20 words
set(islice(infrequent_tokens.items(), 20))
# Out:
# {('consernsrecertification', 1),
#  ('considerd', 1),
#  ('discontued', 1),
#  ('eloras', 2),
#  ('incraese', 1),
#  ('inoutinfarct', 1),
#  ('kreais', 2),
#  ('mracspine', 1),
#  ('naa', 1),
#  ('nebu', 4),
#  ('onld', 1),
#  ('paged', 2),
#  ('perles', 1),
#  ('pitu', 1),
#  ('prison', 3),
#  ('questioned', 3),
#  ('seizuresreferringclinton', 1),
#  ('shrunk', 1),
#  ('throne', 1),
#  ('vain', 2)}

# %% [markdown]
# Most of these are misspellings; some are rare names.

# %%
remove_low_freq_words = [k for k, v in dict(all_words_count).items() if v >= 5]
print("total vocabulary size: {}".format(len(remove_low_freq_words)))
# Out:
# total vocabulary size: 7902

# %% [markdown]
# Tokenize, encode, truncate/pad the conversations:

# %%
vocab_size = (2**np.ceil(np.log(len(remove_low_freq_words))/np.log(2))).astype(np.int64)
tokenize = Tokenizer(num_words=vocab_size)
tokenize.fit_on_texts(df_X_train)

X_train = tokenize.texts_to_sequences(df_X_train)
X_test = tokenize.texts_to_sequences(df_X_test)

# truncate and pad input sequences
max_converse_length = 768
X_train = sequence.pad_sequences(X_train, maxlen=max_converse_length)
X_test = sequence.pad_sequences(X_test, maxlen=max_converse_length)

# %% [markdown]
# Transform the labels:

# %%
encoder = LabelBinarizer()
encoder.fit(df_y_train)
y_train = encoder.transform(df_y_train)
y_test = encoder.transform(df_y_test)

# %% [markdown]
# The mapping between actual topics and their encoded representation:

# %%
# key is textual topics, value is numerical matrix
y_mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))

# %% [markdown]
# ## Define and Fit Models ##

# %%
batch_size = 32
epochs = 16 # 128
embedding_vecor_length = 32
num_classes = len(encoder.classes_)

# %% [markdown]
# [Jason Brownlee recommends a large number of epochs](https://machinelearningmastery.com/improve-deep-learning-performance/ "How To Improve Deep Learning Performance by Jason Brownlee"). I use 16 to iterate faster.

# %% [markdown]
# ### Simple Multi-Layer Perceptron Model ###

# %% [markdown]
# #### Train Model ####

# %%
print('Building model, with dropout layer, no regularization...')
model = Sequential()

model.add(Embedding(vocab_size, embedding_vecor_length, input_length=max_converse_length))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
score = model.evaluate(X_test, y_test,
                       batch_size=batch_size, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Building model, with dropout layer, no regularization...
# Train on 39446 samples, validate on 4383 samples
# Epoch 1/16
# 39446/39446 [==============================] - 211s 5ms/step - loss: 1.3512 - acc: 0.5901 - val_loss: 0.9902 - val_acc: 0.6833
# Epoch 2/16
# 39446/39446 [==============================] - 205s 5ms/step - loss: 0.8480 - acc: 0.7275 - val_loss: 0.9569 - val_acc: 0.6988
# Epoch 3/16
# 39446/39446 [==============================] - 206s 5ms/step - loss: 0.6183 - acc: 0.7956 - val_loss: 1.0299 - val_acc: 0.6929
# Epoch 4/16
# 39446/39446 [==============================] - 202s 5ms/step - loss: 0.4189 - acc: 0.8612 - val_loss: 1.1543 - val_acc: 0.6861
# Epoch 5/16
# 39446/39446 [==============================] - 201s 5ms/step - loss: 0.2797 - acc: 0.9080 - val_loss: 1.3773 - val_acc: 0.6838
# Epoch 6/16
# 39446/39446 [==============================] - 207s 5ms/step - loss: 0.1969 - acc: 0.9342 - val_loss: 1.5610 - val_acc: 0.6815
# Epoch 7/16
# 39446/39446 [==============================] - 201s 5ms/step - loss: 0.1431 - acc: 0.9520 - val_loss: 1.7717 - val_acc: 0.6689
# Epoch 8/16
# 39446/39446 [==============================] - 202s 5ms/step - loss: 0.1162 - acc: 0.9612 - val_loss: 1.9849 - val_acc: 0.6721
# Epoch 9/16
# 39446/39446 [==============================] - 202s 5ms/step - loss: 0.1012 - acc: 0.9670 - val_loss: 2.0498 - val_acc: 0.6733
# Epoch 10/16
# 39446/39446 [==============================] - 202s 5ms/step - loss: 0.0859 - acc: 0.9712 - val_loss: 2.1553 - val_acc: 0.6731
# Epoch 11/16
# 39446/39446 [==============================] - 202s 5ms/step - loss: 0.0806 - acc: 0.9724 - val_loss: 2.3079 - val_acc: 0.6731
# Epoch 12/16
# 39446/39446 [==============================] - 201s 5ms/step - loss: 0.0754 - acc: 0.9753 - val_loss: 2.4102 - val_acc: 0.6699
# Epoch 13/16
# 39446/39446 [==============================] - 201s 5ms/step - loss: 0.0721 - acc: 0.9751 - val_loss: 2.4347 - val_acc: 0.6653
# Epoch 14/16
# 39446/39446 [==============================] - 201s 5ms/step - loss: 0.0656 - acc: 0.9779 - val_loss: 2.5945 - val_acc: 0.6699
# Epoch 15/16
# 39446/39446 [==============================] - 204s 5ms/step - loss: 0.0630 - acc: 0.9787 - val_loss: 2.7056 - val_acc: 0.6685
# Epoch 16/16
# 39446/39446 [==============================] - 203s 5ms/step - loss: 0.0600 - acc: 0.9796 - val_loss: 2.7693 - val_acc: 0.6644
# 4870/4870 [==============================] - 2s 317us/step
# Test score: 2.7422322370922787
# Test accuracy: 0.6655030801066139

# %% [markdown]
# #### Visualize Training History ####

# %%
def summarize_history(model_history):
    sns.tsplot(model_history.history['acc'], color='blue').set_title('model accuracy')
    sns.tsplot(model_history.history['val_acc'], color='green')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='best')

# %%
summarize_history(history)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Looks like the model overfits the data even with a dropout layer. Next we try adding regularization as a remedy for overfitting.

# %% [markdown]
# #### Train Model with L2 Regularization Added ####

# %%
print('Building model, dropout layer, L2 regularization...')
model2 = Sequential()

model2.add(Embedding(vocab_size, embedding_vecor_length, input_length=max_converse_length))
model2.add(Flatten())
model2.add(Dense(512, input_shape=(vocab_size,), kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(num_classes, activation='softmax'))
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history2 = model2.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_split=0.1)
score = model2.evaluate(X_test, y_test,
                       batch_size=batch_size, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Building model, dropout layer, L2 regularization...
# Train on 39446 samples, validate on 4383 samples
# Epoch 1/16
# 39446/39446 [==============================] - 262s 7ms/step - loss: 2.0377 - acc: 0.5215 - val_loss: 1.7694 - val_acc: 0.6055
# Epoch 2/16
# 39446/39446 [==============================] - 253s 6ms/step - loss: 1.7386 - acc: 0.6343 - val_loss: 1.7453 - val_acc: 0.6452
# Epoch 3/16
# 39446/39446 [==============================] - 255s 6ms/step - loss: 1.6724 - acc: 0.6695 - val_loss: 1.7461 - val_acc: 0.6578
# Epoch 4/16
# 39446/39446 [==============================] - 249s 6ms/step - loss: 1.6572 - acc: 0.6852 - val_loss: 1.7250 - val_acc: 0.6639
# Epoch 5/16
# 39446/39446 [==============================] - 254s 6ms/step - loss: 1.6379 - acc: 0.6967 - val_loss: 1.7841 - val_acc: 0.6642
# Epoch 6/16
# 39446/39446 [==============================] - 254s 6ms/step - loss: 1.6403 - acc: 0.7074 - val_loss: 1.7682 - val_acc: 0.6724
# Epoch 7/16
# 39446/39446 [==============================] - 254s 6ms/step - loss: 1.6205 - acc: 0.7206 - val_loss: 1.8203 - val_acc: 0.6687
# Epoch 8/16
# 39446/39446 [==============================] - 252s 6ms/step - loss: 1.6252 - acc: 0.7312 - val_loss: 1.8311 - val_acc: 0.6685
# Epoch 9/16
# 39446/39446 [==============================] - 254s 6ms/step - loss: 1.6090 - acc: 0.7420 - val_loss: 1.8441 - val_acc: 0.6751
# Epoch 10/16
# 39446/39446 [==============================] - 254s 6ms/step - loss: 1.6083 - acc: 0.7539 - val_loss: 2.0402 - val_acc: 0.6571
# Epoch 11/16
# 39446/39446 [==============================] - 255s 6ms/step - loss: 1.6094 - acc: 0.7610 - val_loss: 2.0102 - val_acc: 0.6632
# Epoch 12/16
# 39446/39446 [==============================] - 255s 6ms/step - loss: 1.5966 - acc: 0.7772 - val_loss: 2.2287 - val_acc: 0.6594
# Epoch 13/16
# 39446/39446 [==============================] - 255s 6ms/step - loss: 1.6032 - acc: 0.7852 - val_loss: 2.2233 - val_acc: 0.6496
# Epoch 14/16
# 39446/39446 [==============================] - 253s 6ms/step - loss: 1.5816 - acc: 0.7958 - val_loss: 2.2045 - val_acc: 0.6582
# Epoch 15/16
# 39446/39446 [==============================] - 255s 6ms/step - loss: 1.5811 - acc: 0.8071 - val_loss: 2.3067 - val_acc: 0.6454
# Epoch 16/16
# 39446/39446 [==============================] - 263s 7ms/step - loss: 1.5755 - acc: 0.8165 - val_loss: 2.4011 - val_acc: 0.6434
# 4870/4870 [==============================] - 5s 950us/step
# Test score: 2.3926580364454453
# Test accuracy: 0.6429158111005349

# %% [markdown]
# #### Visualize Training History ####

# %%
summarize_history(history2)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# The performance is similar to the previous model.

# %% [markdown]
# For which categories does the model make wrong predictions?

# %% [markdown]
# #### Produce Confusion Matrix ####

# %%
def plot_confusion_matrix(model):
    prediction = model.predict(X_test, batch_size=batch_size)
    predicted_label = encoder.classes_[np.argmax(prediction, axis=1)]

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(df_y_test, predicted_label)
    # normalize confusion matrix as classes are not balanced
    cnf_matrix_normalized = cnf_matrix/cnf_matrix.sum(axis=1)[:, np.newaxis]
    # heatmap 
    plt.figure(figsize = (20, 15))
    sns.heatmap(cnf_matrix_normalized, cmap="GnBu", linewidths=0.1, linecolor='gray', \
                xticklabels=encoder.classes_, yticklabels=encoder.classes_)

    plt.ylabel('True category', fontsize=25)
    plt.xlabel('Predicted category', fontsize=25)

    plt.title("Normalized Confusion Matrix", fontsize=30)

# %%
plot_confusion_matrix(model2)

# %% [markdown]
# Look at a few predictions that the prediction was wrong.

# %%
def concat_prediction(prediction_model):
    predicted_label = encoder.inverse_transform(prediction_model.predict(X_test))
    df_diff_model = df_y_test[df_y_test != predicted_label]
    df_y_compare = pd.concat([df_y_test, pd.Series(predicted_label, index=df_y_test.index)], axis=1)

    for i in list(df_diff_model.index[:10]):
        print(i)
        print(df_X_test.loc[i])
        print('Actual label:' + df_y_test.loc[i])
        print("Predicted label: " + df_y_compare[0].loc[i])
        print("\n")

# %%
print("Look at 10 wrong predictions:")
concat_prediction(model2)
# Out:
# Look at 10 wrong predictions:
# 38239
# lm mom let know need letter state glafira income pm lisa mohamed rn mom come patient assistant paperwork vimpat know must give letter say income would go speak go ahead fax patient assistance paperwork last week ucb without letter know receive need mom time tell also go tell mom next time able help without spanish interpreter
# Actual label:OTHERS
# Predicted label: SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)
#
#
# 3745
# wife return phone wife say wait name spouse appointment wife state someone wife say wasnt rna shes upset bc shes impression someone office say patient driving labtype wife still wouldnt say regard labtype wife request work appointment wgf refuse see np prior authorization rna follow lmo ident vm tcb discuss jennifer taylor rn rna follow rc wife please mary gryder rna follow lmo ident vm tcb discuss spot block w wgf family member jennifer taylor rn wife return phone wife say wait next week patient see doctor
# Actual label:NEW APPOINTMENT
# Predicted label: SYMPTOMS
#
#
# 2349
# aetna status lidoderm patch patient clinic name aetna pharmacy mgmt reason call detail aetna status prior authorization lidoderm patch ref lidoderma patch deny aetna pharmacy phone complete mary morton lpn timephrase pm clinical list change
# Actual label:FOLLOW UP ON PREVIOUS REQUEST
# Predicted label: QUERIES FROM PHARMACY
#
#
# 2970
# patient list medication patient prescription prescription comment patient list medication amloditine besylate mg tab daily mouth citalopram mg tab daily mouth donepezil mg tab daily mouth drugname mg tab daily mouth venlafaxine er mg cap daily mouth timephrase pm verify medicine patient chart change medication phone complete lea falk cma
# Actual label:MEDICATION RELATED
# Predicted label: REFILL
#
#
# 45484
# sooner rov timephrase patient patient stomach issue slightly dehydrate want know symptom could relate informed patient infection cause exacerbation bowel change sometimes sign flare hospitalist able good ass symptom cause tx patient verbalize understanding would like know come sooner appointment rov timephrase discharge hospital record fax rna well rna follow yes let see harry md rna follow flag schedule schedule hl soon possible mary morton lpn rna follow patient notify uti need treat appoitnment schedule week phone complete
# Actual label:SYMPTOMS
# Predicted label: MEDICATION RELATED
#
#
# 3686
# mom return rn name mom mom return rn please back kimberly gerald mom aware labtype result copy fax grow child hope common office phone complete patient verbalized understanding instruction nicole lyon rn
# Actual label:SHARING OF LAB RECORDS (FAX, E-MAIL, ETC.)
# Predicted label: NEW APPOINTMENT
#
#
# 5372
# pm johnny beal pcp say ok use uhc compass referral solumedrol visit jb
# Actual label:CHANGE OF PROVIDER
# Predicted label: OTHERS
#
#
# 25794
# patient clld speak rn cambia patient patient state rx cambium really expensive thats even discount card give shed like know generic medication please back advise rna follow pharmacy discuss rx status see need prior authorization anything pharmacy state patient take rx remove file patient take prescription protocol therefore able check see need prior authorization coverage phone complete jennifer taylor rn timephrase pm
# Actual label:MEDICATION RELATED
# Predicted label: PRIOR AUTHORIZATION
#
#
# 24805
# klonopin drugname rx pharmacy name rite aid reason call detail rite aid patient klonopin mg order transfer notice patient get drugname another provider pharmacy want know rna provider want patient medication list patient medication list please merideth verify patient go take aware use drugname tremor drugname anxiety use time discuss stacy deese anp merideth notify mary beal lpn
# Actual label:QUERIES FROM PHARMACY
# Predicted label: MEDICATION RELATED
#
#
# 2839
# lmtcb schedule appointment refill lisa mohamed rn patient need appointment last see request drugname rx
# Actual label:NEW APPOINTMENT
# Predicted label: REFILL

# %% [markdown]
# ### RNN LSTM ###

# %% [markdown]
# #### Train Model ####

# %%
print('Building model, RNN LSTM...')

model3 = Sequential()
model3.add(Embedding(vocab_size, embedding_vecor_length, input_length=max_converse_length))
model3.add(LSTM(64)) # try 128
model3.add(Dense(num_classes, activation='softmax'))
model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history3 = model3.fit(X_train, y_train, \
                      batch_size=batch_size, \
                      epochs=epochs, \
                      verbose=1, \
                      validation_split=0.1)

score = model3.evaluate(X_test, y_test, \
                        batch_size=batch_size, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Building model, RNN LSTM...
# Train on 39446 samples, validate on 4383 samples
# Epoch 1/16
# 39446/39446 [==============================] - 505s 13ms/step - loss: 1.6768 - acc: 0.4885 - val_loss: 1.3064 - val_acc: 0.5966
# Epoch 2/16
# 39446/39446 [==============================] - 496s 13ms/step - loss: 1.1156 - acc: 0.6566 - val_loss: 1.0685 - val_acc: 0.6612
# Epoch 3/16
# 39446/39446 [==============================] - 495s 13ms/step - loss: 0.9110 - acc: 0.7149 - val_loss: 0.8971 - val_acc: 0.7102
# Epoch 4/16
# 39446/39446 [==============================] - 488s 12ms/step - loss: 0.7927 - acc: 0.7454 - val_loss: 0.8477 - val_acc: 0.7308
# Epoch 5/16
# 39446/39446 [==============================] - 488s 12ms/step - loss: 0.7192 - acc: 0.7667 - val_loss: 0.8256 - val_acc: 0.7337
# Epoch 6/16
# 39446/39446 [==============================] - 486s 12ms/step - loss: 0.6609 - acc: 0.7831 - val_loss: 0.8339 - val_acc: 0.7349
# Epoch 7/16
# 39446/39446 [==============================] - 487s 12ms/step - loss: 0.6097 - acc: 0.7990 - val_loss: 0.8370 - val_acc: 0.7324
# Epoch 8/16
# 39446/39446 [==============================] - 485s 12ms/step - loss: 0.5649 - acc: 0.8129 - val_loss: 0.8517 - val_acc: 0.7305
# Epoch 9/16
# 39446/39446 [==============================] - 486s 12ms/step - loss: 0.5200 - acc: 0.8274 - val_loss: 0.8806 - val_acc: 0.7248
# Epoch 10/16
# 39446/39446 [==============================] - 487s 12ms/step - loss: 0.4795 - acc: 0.8406 - val_loss: 0.9172 - val_acc: 0.7217
# Epoch 11/16
# 39446/39446 [==============================] - 487s 12ms/step - loss: 0.4404 - acc: 0.8554 - val_loss: 0.9758 - val_acc: 0.7157
# Epoch 12/16
# 39446/39446 [==============================] - 488s 12ms/step - loss: 0.4043 - acc: 0.8648 - val_loss: 1.0068 - val_acc: 0.7212
# Epoch 13/16
# 39446/39446 [==============================] - 489s 12ms/step - loss: 0.3686 - acc: 0.8780 - val_loss: 1.0856 - val_acc: 0.7112
# Epoch 14/16
# 39446/39446 [==============================] - 491s 12ms/step - loss: 0.3368 - acc: 0.8913 - val_loss: 1.1370 - val_acc: 0.7123
# Epoch 15/16
# 39446/39446 [==============================] - 486s 12ms/step - loss: 0.3047 - acc: 0.8999 - val_loss: 1.1629 - val_acc: 0.7041
# Epoch 16/16
# 39446/39446 [==============================] - 487s 12ms/step - loss: 0.2751 - acc: 0.9128 - val_loss: 1.2316 - val_acc: 0.7045
# 4870/4870 [==============================] - 10s 2ms/step
# Test score: 1.2760132219879534
# Test accuracy: 0.6997946611909651

# %% [markdown]
# #### Visualize Training History ####

# %%
summarize_history(history3)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Produce Confusion Matrix ####

# %%
plot_confusion_matrix(model3)

# %%
print("Look at 10 wrong predictions:")
concat_prediction(model3)
# Out:
# Look at 10 wrong predictions:
# 45474
# letter faa regard cpap labtype sleep apnea patient call need letter faa say cpap labtype sleep apnea please patient timephrase discuss rna follow spoke patient suggest need schedule iov see seven year say check see need appointment write letter need yeh dont really consider patient havent see year overly accomodating sight unseen alternativ presumably see recently write letter atp rna follow iov notify read
# Actual label:SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)
# Predicted label: PROVIDER
#
#
# 38239
# lm mom let know need letter state glafira income pm lisa mohamed rn mom come patient assistant paperwork vimpat know must give letter say income would go speak go ahead fax patient assistance paperwork last week ucb without letter know receive need mom time tell also go tell mom next time able help without spanish interpreter
# Actual label:OTHERS
# Predicted label: SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)
#
#
# 3745
# wife return phone wife say wait name spouse appointment wife state someone wife say wasnt rna shes upset bc shes impression someone office say patient driving labtype wife still wouldnt say regard labtype wife request work appointment wgf refuse see np prior authorization rna follow lmo ident vm tcb discuss jennifer taylor rn rna follow rc wife please mary gryder rna follow lmo ident vm tcb discuss spot block w wgf family member jennifer taylor rn wife return phone wife say wait next week patient see doctor
# Actual label:NEW APPOINTMENT
# Predicted label: QUERY ON CURRENT APPOINTMENT
#
#
# 27027
# wcb amedysis incoming name amedysis home health reason call detail rn state hed like speak rn ov note receive show patient see timephrase please back advise rna follow rn leave message answer labtype request return rna erica adam rn see note day md
# Actual label:OTHERS
# Predicted label: LAB RESULTS
#
#
# 21192
# strattera sample name mom prescription prescription comment patient mom would like know come timephrase pick strattera mg sample offer say patient pill leave timephrase pm advd mom pick sample mg strattera marcia richardson lpn timephrase pm put maureen gonzales np timephrase pm
# Actual label:REFILL
# Predicted label: MEDICATION RELATED
#
#
# 2349
# aetna status lidoderm patch patient clinic name aetna pharmacy mgmt reason call detail aetna status prior authorization lidoderm patch ref lidoderma patch deny aetna pharmacy phone complete mary morton lpn timephrase pm clinical list change
# Actual label:FOLLOW UP ON PREVIOUS REQUEST
# Predicted label: PRIOR AUTHORIZATION
#
#
# 2970
# patient list medication patient prescription prescription comment patient list medication amloditine besylate mg tab daily mouth citalopram mg tab daily mouth donepezil mg tab daily mouth drugname mg tab daily mouth venlafaxine er mg cap daily mouth timephrase pm verify medicine patient chart change medication phone complete lea falk cma
# Actual label:MEDICATION RELATED
# Predicted label: REFILL
#
#
# 45484
# sooner rov timephrase patient patient stomach issue slightly dehydrate want know symptom could relate informed patient infection cause exacerbation bowel change sometimes sign flare hospitalist able good ass symptom cause tx patient verbalize understanding would like know come sooner appointment rov timephrase discharge hospital record fax rna well rna follow yes let see harry md rna follow flag schedule schedule hl soon possible mary morton lpn rna follow patient notify uti need treat appoitnment schedule week phone complete
# Actual label:SYMPTOMS
# Predicted label: MEDICATION RELATED
#
#
# 5372
# pm johnny beal pcp say ok use uhc compass referral solumedrol visit jb
# Actual label:CHANGE OF PROVIDER
# Predicted label: NEW APPOINTMENT
#
#
# 46200
# labtype result letter mail patient patient labtype result mriradiology detail please patient labtype result rna follow rn speak pt aware receive note labtype result say wait read letter receive decline read phone complete patient verbalized understanding instruction erica adam rn
# Actual label:LAB RESULTS
# Predicted label: SHARING OF LAB RECORDS (FAX, E-MAIL, ETC.)

# %% [markdown]
# ### CNN ###

# %% [markdown]
# #### Train Model ####

# %%
print('Building model, CNN...')

# create the model
model4 = Sequential()
model4.add(Embedding(vocab_size, embedding_vecor_length, input_length=max_converse_length))
model4.add(Conv1D(activation="relu", filters=32, kernel_size=3, padding="same"))
model4.add(MaxPooling1D(pool_size=2))
model4.add(Dropout(0.5)) # dropout after pooling
model4.add(Flatten())
model4.add(Dense(128, activation='relu'))

model4.add(Dense(num_classes, activation='softmax'))
model4.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# print(model4.summary())

history4 = model4.fit(X_train, y_train, \
                      batch_size=batch_size, \
                      epochs=epochs, \
                      verbose=1, \
                      validation_split=0.1)

score = model4.evaluate(X_test, y_test, \
                        batch_size=batch_size, verbose=1)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Building model, CNN...
# Train on 39446 samples, validate on 4383 samples
# Epoch 1/16
# 39446/39446 [==============================] - 56s 1ms/step - loss: 1.4438 - acc: 0.5573 - val_loss: 1.0904 - val_acc: 0.6658
# Epoch 2/16
# 39446/39446 [==============================] - 55s 1ms/step - loss: 0.9749 - acc: 0.6907 - val_loss: 0.9315 - val_acc: 0.7075
# Epoch 3/16
# 39446/39446 [==============================] - 55s 1ms/step - loss: 0.8340 - acc: 0.7301 - val_loss: 0.9107 - val_acc: 0.7027
# Epoch 4/16
# 39446/39446 [==============================] - 56s 1ms/step - loss: 0.7535 - acc: 0.7539 - val_loss: 0.9050 - val_acc: 0.7132
# Epoch 5/16
# 39446/39446 [==============================] - 57s 1ms/step - loss: 0.6833 - acc: 0.7723 - val_loss: 0.9356 - val_acc: 0.7059
# Epoch 6/16
# 39446/39446 [==============================] - 58s 1ms/step - loss: 0.6273 - acc: 0.7899 - val_loss: 0.9485 - val_acc: 0.7096
# Epoch 7/16
# 39446/39446 [==============================] - 55s 1ms/step - loss: 0.5814 - acc: 0.8047 - val_loss: 0.9600 - val_acc: 0.7029
# Epoch 8/16
# 39446/39446 [==============================] - 54s 1ms/step - loss: 0.5402 - acc: 0.8155 - val_loss: 1.0306 - val_acc: 0.6997
# Epoch 9/16
# 39446/39446 [==============================] - 56s 1ms/step - loss: 0.5007 - acc: 0.8279 - val_loss: 1.0777 - val_acc: 0.6950
# Epoch 10/16
# 39446/39446 [==============================] - 53s 1ms/step - loss: 0.4651 - acc: 0.8411 - val_loss: 1.0737 - val_acc: 0.7016
# Epoch 11/16
# 39446/39446 [==============================] - 53s 1ms/step - loss: 0.4369 - acc: 0.8509 - val_loss: 1.1321 - val_acc: 0.6931
# Epoch 12/16
# 39446/39446 [==============================] - 54s 1ms/step - loss: 0.4145 - acc: 0.8566 - val_loss: 1.2058 - val_acc: 0.6968
# Epoch 13/16
# 39446/39446 [==============================] - 54s 1ms/step - loss: 0.3895 - acc: 0.8645 - val_loss: 1.2542 - val_acc: 0.6961
# Epoch 14/16
# 39446/39446 [==============================] - 54s 1ms/step - loss: 0.3706 - acc: 0.8727 - val_loss: 1.2352 - val_acc: 0.6854
# Epoch 15/16
# 39446/39446 [==============================] - 58s 1ms/step - loss: 0.3501 - acc: 0.8776 - val_loss: 1.2896 - val_acc: 0.6988
# Epoch 16/16
# 39446/39446 [==============================] - 59s 2ms/step - loss: 0.3430 - acc: 0.8806 - val_loss: 1.3137 - val_acc: 0.6879
# 4870/4870 [==============================] - 1s 289us/step
# Test score: 1.351599125095951
# Test accuracy: 0.6831622176346592

# %% [markdown]
# #### Visualize Training History ####

# %%
summarize_history(history4)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Produce Confusion Matrix ####

# %%
plot_confusion_matrix(model4)

# %%
print("Look at 10 wrong predictions:")
concat_prediction(model4)
# Out:
# Look at 10 wrong predictions:
# 38239
# lm mom let know need letter state glafira income pm lisa mohamed rn mom come patient assistant paperwork vimpat know must give letter say income would go speak go ahead fax patient assistance paperwork last week ucb without letter know receive need mom time tell also go tell mom next time able help without spanish interpreter
# Actual label:OTHERS
# Predicted label: SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)
#
#
# 27027
# wcb amedysis incoming name amedysis home health reason call detail rn state hed like speak rn ov note receive show patient see timephrase please back advise rna follow rn leave message answer labtype request return rna erica adam rn see note day md
# Actual label:OTHERS
# Predicted label: PROVIDER
#
#
# 2349
# aetna status lidoderm patch patient clinic name aetna pharmacy mgmt reason call detail aetna status prior authorization lidoderm patch ref lidoderma patch deny aetna pharmacy phone complete mary morton lpn timephrase pm clinical list change
# Actual label:FOLLOW UP ON PREVIOUS REQUEST
# Predicted label: QUERIES FROM PHARMACY
#
#
# 2970
# patient list medication patient prescription prescription comment patient list medication amloditine besylate mg tab daily mouth citalopram mg tab daily mouth donepezil mg tab daily mouth drugname mg tab daily mouth venlafaxine er mg cap daily mouth timephrase pm verify medicine patient chart change medication phone complete lea falk cma
# Actual label:MEDICATION RELATED
# Predicted label: REFILL
#
#
# 45484
# sooner rov timephrase patient patient stomach issue slightly dehydrate want know symptom could relate informed patient infection cause exacerbation bowel change sometimes sign flare hospitalist able good ass symptom cause tx patient verbalize understanding would like know come sooner appointment rov timephrase discharge hospital record fax rna well rna follow yes let see harry md rna follow flag schedule schedule hl soon possible mary morton lpn rna follow patient notify uti need treat appoitnment schedule week phone complete
# Actual label:SYMPTOMS
# Predicted label: MEDICATION RELATED
#
#
# 5372
# pm johnny beal pcp say ok use uhc compass referral solumedrol visit jb
# Actual label:CHANGE OF PROVIDER
# Predicted label: OTHERS
#
#
# 1101
# fyi name mom appointment patient mom request work appointment say daughter fell room hit head patient trouble walking nauseated spoke mom fell hit head timephrase sleep since wake nauseated trouble walking head pound mom want see timephrase mom advise take closest ed evaluation today rov make pm timephrase doctor provider notify rna follow mom ask come could testing appointment wooten mom agree phone complete appointment schedule family member verbalize understanding instruction mike hale
# Actual label:NEW APPOINTMENT
# Predicted label: MEDICATION RELATED
#
#
# 25794
# patient clld speak rn cambia patient patient state rx cambium really expensive thats even discount card give shed like know generic medication please back advise rna follow pharmacy discuss rx status see need prior authorization anything pharmacy state patient take rx remove file patient take prescription protocol therefore able check see need prior authorization coverage phone complete jennifer taylor rn timephrase pm
# Actual label:MEDICATION RELATED
# Predicted label: PRIOR AUTHORIZATION
#
#
# 27269
# patient state see pcp write rx pm brittany estep rn lov patient r cancelled subsequent two followup rov need continued careprescription authorization
# Actual label:NEW APPOINTMENT
# Predicted label: OTHERS
#
#
# 3102
# rc insurance update quantity override adderall xr mg name patient lisadr perkins prescription prescription comment paulette transfer patient indicating rex pharmacy able fill adderall xr due amount per day sure patient refer rex spoke gordon rna pharmacy still script write timephrase yet mail advise hold onto script sort speak rex pharmacy state bcbs pay cap per day patient script indicate tab tabs noon need script split separate dos however physician chooses advise lisa mohamed rn rex pharmacy submit rx prior auth rex pharmacy speak timephrase pharmacist go ahead submit rx fax timephrase pm rna follow per registration bcbsnc prior authorization form phone number unable prior authorization go cover medicine try fill eligibility find need wait prior authorization request rex pharmacy patient take adderall xr mg dos start take much
# Actual label:SHARING OF HEALTH RECORDS (FAX, E-MAIL, ETC.)
# Predicted label: PRIOR AUTHORIZATION

# %% [markdown]
# Observations:
# * Multi-layer perceptron, RNN LSTM, and CNN all have similar performance. RNN LSTM performs marginally better in terms of overall accuracy.
# * CNN, with much fewer parameters to train than RNN LSTM, trains faster than RNN as one expects. In future practice I will run CNN before RNN in order to iterate faster.
# * Comparing the confusion matrices of these models, we see that they make correct predictions in approximately the same classes of target (LAB RESULTS through PROVIDER, QUERIES FROM PHARMACY through SYMPTOMS in the confusion matrices). Ensembling these models may not improve performance.
# * Regularization does not improve performance.
# * Looking at those 10 samples of incorrect predictions, I can see why they were labeled the way they were but I cannot see a pattern that I can use to improve the models. Domain knowledge about the classification rules is needed!
